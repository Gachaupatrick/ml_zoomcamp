# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Q1. Pandas version
# What version of Pandas did you install?
# - 3.0.5

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
data = 'https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv'
# !wget -nc $data
# Out:
# File ‘car_fuel_efficiency_2026.csv’ already there; not retrieving.

# %%
df = pd.read_csv("car_fuel_efficiency_2026.csv")
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %% [markdown]
# # Q2. Records count
# How many records are in the dataset?
#
# - 5000
# - 9000
# - 10000
# - 15000
#
# Answer
#
# - 10,000

# %%
df.shape
# Out:
# (10000, 11)

# %% [markdown]
# # Q3. Fuel types
# How many fuel types are presented in the dataset?
#
# - 1
# - 2
# - 3
# - 4
#
# Answer
# - 3

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Gasoline    6913
# Diesel      2053
# Hybrid      1034
# Name: count, dtype: int64

# %% [markdown]
# # Q4. Missing values
# How many columns in the dataset have missing values?
#
# - 0
# - 1
# - 2
# - 3
# - 4
#
# Answer
# - 2

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# # Q5. Max fuel efficiency
# What's the maximum fuel efficiency of cars from Asia?
#
# - 21.2
# - 31.2
# - 41.2
# - 51.2
#
# Answer
# - 41.2

# %%
Asia = df[df['origin'] == 'Asia']
(Asia['fuel_efficiency_mpg'].max())
# Out:
# np.float64(41.2)

# %% [markdown]
# # Q6. Median value of horsepower
# - Find the median value of the horsepower column in the dataset. - *254*
# - Next, calculate the most frequent value of the same horsepower column. - *252*
# - Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step.
# - Now, calculate the median value of horsepower once again. - *252*
#
# Has it changed?
#
# - Yes, it increased
# - Yes, it decreased
# - No
#
# Answer
# - Yes, it decreased

# %%
#Find the median value of the horsepower column in the dataset.
print('median', df['horsepower'].median())

#Next, calculate the most frequent value of the same horsepower column.
print('mode', df['horsepower'].mode().tolist())
# Out:
# median 254.0
# mode [252.0]

# %%
#Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mode()[0])
print('median', df['horsepower'].median())
# Out:
# median 252.0

# %% [markdown]
# # Q7. Sum of weights
# - Select all the cars from Asia
# - Select only columns vehicle_weight and model_year
# - Select the first 7 values
# - Get the underlying NumPy array. Let's call it X.
# - Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T.
#
# Let's call the result XTX.
# - Invert XTX.
# - Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200].
# - Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
#
# What's the sum of all the elements of the result?
#
# Answer
# - np.float64(0.36919696904925486)

# %%
cols = ['vehicle_weight', 'model_year']
X = Asia[cols][:7]

#Get the underlying NumPy array. Let's call it X
X = X.values
X

#Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T.
XTX = X.T @ X

#Invert XTX
XTX_inv = np.linalg.inv(XTX)

#Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200]
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

#Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
w = XTX_inv @ X.T @ y

#What's the sum of all the elements of the result?
np.sum(w)
# Out:
# np.float64(0.36919696904925486)
